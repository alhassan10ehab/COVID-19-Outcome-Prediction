# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load the data
df = pd.read_csv('/content/data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  location  country  gender   age  vis_wuhan  from_wuhan  \
# 0           0       104        8       1  66.0          1           0
# 1           1       101        8       0  56.0          0           1
# 2           2       137        8       1  46.0          0           1
# 3           3       116        8       0  60.0          1           0
# 4           4       116        8       1  58.0          0           0
#
#    symptom1  symptom2  symptom3  symptom4  symptom5  symptom6  diff_sym_hos  \
# 0        14        31        19        12         3         1             8
# 1        14        31        19        12         3         1             0
# 2        14        31        19        12         3         1            13
# 3        14        31        19        12         3         1             0
# 4        14        31        19        12         3         1             0
#
#    result
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#print dimensions 
df.shape
# Out:
# (863, 15)

# %%
#plot the number of sample for each class
plt.hist(df['result'])
plt.show()

# %%
#correllation among all features
df.corr()
# Out:
#               Unnamed: 0  location   country    gender       age  vis_wuhan  \
# Unnamed: 0      1.000000 -0.123488  0.311170  0.182616  0.069737  -0.293568
# location       -0.123488  1.000000  0.309347  0.030077 -0.027330   0.022821
# country         0.311170  0.309347  1.000000  0.193208  0.072339  -0.149798
# gender          0.182616  0.030077  0.193208  1.000000 -0.020662  -0.005588
# age             0.069737 -0.027330  0.072339 -0.020662  1.000000  -0.157173
# vis_wuhan      -0.293568  0.022821 -0.149798 -0.005588 -0.157173   1.000000
# from_wuhan     -0.223951  0.080120 -0.194170 -0.138997 -0.051229  -0.154200
# symptom1        0.053031  0.033078 -0.078971  0.146706 -0.209028   0.087330
# symptom2        0.061755  0.017961 -0.085210  0.116159 -0.127251   0.094360
# symptom3        0.082368  0.010472 -0.042933  0.090858 -0.074863   0.086113
# symptom4        0.038603 -0.026823 -0.018526  0.021882 -0.069396   0.063738
# symptom5       -0.017153  0.033692 -0.009371  0.026320  0.049817   0.025780
# symptom6        0.022695  0.015341 -0.004384  0.039867  0.055145   0.016062
# diff_sym_hos   -0.129907 -0.119397 -0.146037 -0.176528  0.074573   0.065908
# result          0.046838  0.046240 -0.094443 -0.061441  0.515127  -0.151122
#
#               from_wuhan  symptom1  symptom2  symptom3  symptom4  symptom5  \
# Unnamed: 0     -0.223951  0.053031  0.061755  0.082368  0.038603 -0.017153
# location        0.080120  0.033078  0.017961  0.010472 -0.026823  0.033692
# country        -0.194170 -0.078971 -0.085210 -0.042933 -0.018526 -0.009371
# gender         -0.138997  0.146706  0.116159  0.090858  0.021882  0.026320
# age            -0.051229 -0.209028 -0.127251 -0.074863 -0.069396  0.049817
# vis_wuhan      -0.154200  0.087330  0.094360  0.086113  0.063738  0.025780
# from_wuhan      1.000000  0.036539  0.046923  0.068144  0.021704  0.018999
# symptom1        0.036539  1.000000  0.519404  0.260397  0.095402 -0.002658
# symptom2        0.046923  0.519404  1.000000  0.530968  0.329583  0.159823
# symptom3        0.068144  0.260397  0.530968  1.000000  0.429853  0.120301
# symptom4        0.021704  0.095402  0.329583  0.429853  1.000000  0.277558
# symptom5        0.018999 -0.002658  0.159823  0.120301  0.277558  1.000000
# symptom6        0.011837  0.086430  0.072975  0.146347  0.110553  0.265954
# diff_sym_hos    0.019706 -0.141160 -0.119052 -0.124293 -0.089592  0.003757
# result          0.128314 -0.163039 -0.103270 -0.074982 -0.108723  0.020676
#
#               symptom6  diff_sym_hos    result
# Unnamed: 0    0.022695     -0.129907  0.046838
# location      0.015341     -0.119397  0.046240
# country      -0.004384     -0.146037 -0.094443
# gender        0.039867     -0.176528 -0.061441
# age           0.055145      0.074573  0.515127
# vis_wuhan     0.016062      0.065908 -0.151122
# from_wuhan    0.011837      0.019706  0.128314
# symptom1      0.086430     -0.141160 -0.163039
# symptom2      0.072975     -0.119052 -0.103270
# symptom3      0.146347     -0.124293 -0.074982
# symptom4      0.110553     -0.089592 -0.108723
# symptom5      0.265954      0.003757  0.020676
# symptom6      1.000000     -0.000067  0.012882
# diff_sym_hos -0.000067      1.000000  0.219116
# result        0.012882      0.219116  1.000000

# %%
#heat map for features correlation
plt.figure(figsize =(8,8))
plt.imshow(df.corr())
plt.show()

# %%
plt.figure(figsize =(15,10))
sns.heatmap(df.corr(), annot=True)
plt.show()
